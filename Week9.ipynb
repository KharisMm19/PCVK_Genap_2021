# %% [markdown]
# <a href="https://colab.research.google.com/github/KharisMm19/PCVK_Genap_2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Import beberapa library berikut yang akan digunakan selama uji coba praktikum minggu ke-6 berikut

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
from skimage import io
from skimage import transform
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.morphology import (erosion, dilation, closing, opening, area_closing, area_opening)
from skimage.color import rgb2gray

# %% [markdown]
# 3. Buatlah fungsi dilasi serta tampilkan hasil dilasi pada citra dengan Structuring Element Dilasi (SED) berbentuk square 5 x 5 tanpa menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/j.jpg')

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc606e5e290>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %% [markdown]
# 4. Buatlah fungsi erosi serta tampilkan hasil erosi pada citra dengan Structuring Element Erosi (SE) berbentuk square 5 x 5 tanpa menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png

# %%
img1= cv.imread('/content/drive/MyDrive/PCVK_MM/Images/j.jpg', 0)

m,n= img1.shape 

plt.imshow(img1, cmap="gray")

k=5
SE= np.ones((k,k), dtype=np.uint8)
constant= (k-1)//2

imgErode= np.zeros((m,n), dtype=np.uint8)

for i in range(constant, m-constant):
  for j in range(constant,n-constant):
    temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
    product= temp*SE
    imgErode[i,j]= np.min(product)
plt.subplot(121), plt.imshow(img1, cmap ="gray"), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(imgErode, cmap="gray"), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc606e37610>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %% [markdown]
# 4. Buatlah fungsi erosi serta tampilkan hasil erosi pada citra dengan Structuring Element Erosi (SE) berbentuk square 5 x 5 tanpa menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc606809bd0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %% [markdown]
# 6. Buatlah program implementasi operasi dilasi Structuring Element Erosi (SE) berbentuk square 5 x 5 dengan menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc6067d0b90>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %% [markdown]
# 7. Buatlah program implementasi operasi opening dengan Structuring Element
# berbentuk square 7 x 7 tanpa dan dengan menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc606721c50>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %% [markdown]
# 8. Buatlah program implementasi operasi closing dengan Structuring Element berbentuk square 7 x 7 tanpa dan dengan menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc6065f0f10>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %% [markdown]
# 9. Buatlah program implementasi operasi dilasi dengan Structuring Element berbentuk Cross 3 x 3 dan 5 x 5, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
#SED = Cross 3
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc60658e550>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %%
#SED = Cross 5
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc6064a5310>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 5x5'))

# %% [markdown]
# 10. Buatlah program implementasi operasi dilasi dengan Structuring Element berbentuk Circular 3 x 3 dan 5 x 5, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
#SED = Circular 3
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi Circular 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc606211c50>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi Circular 3x3'))

# %%
#SED = Circle 5
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi Circular 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc606e3d190>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi Circular 5x5'))

# %% [markdown]
# 11. Buatlah program implementasi operasi erosi dengan Structuring Element berbentuk Rectangle 3 x 5 dan 5 x 7, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
#SE = Rectangle 3x5
kernel = cv.getStructuringElement(cv.MORPH_RECT, (3, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Erosi Rectangle 3x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc6060beb10>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi Rectangle 3x5'))

# %%
#SE = Rectangle 5x7
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Erosi Rectangle 5x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc605fcfdd0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi Rectangle 5x7'))

# %% [markdown]
# 12. Buatlah program implementasi operasi erosi dengan Structuring Element berbentuk Line Vertikal 3 dan 5, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
#SE = Line Vertikal 3
kernel = np.ones((3,1), np.uint8)
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi Line Vertikal 3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc605f17ed0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi Line Vertikal 3'))

# %%
#SE = Line Vertikal 5
kernel = np.ones((5,1), np.uint8)
cross3 = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi Line Vertikal 5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fc605df62d0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi Line Vertikal 5'))
